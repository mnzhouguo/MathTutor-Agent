# %%
# 导入必要的库
import sys
from pathlib import Path

# 添加项目路径
# 导入必要的库
import sys
import os
from pathlib import Path

# 添加项目路径 - 修复版本
# 方法1: 使用当前工作目录
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from services.deepseek_service import DeepSeekClient
from services.simple_chat_service import SimpleChatService

# %%
# 初始化SimpleChatService
agent= SimpleChatService()
agent.chat("Hello, how are you?")
# Out:
# {'response': "Hello! I'm doing great, thank you for asking! 😊 I'm here and ready to help you with any math questions you might have. Whether it's algebra, geometry, fractions, or anything else that's puzzling you - just let me know what you'd like to work on today! \n\nHow are you doing? Ready to dive into some math learning together?",
#  'history': [{'role': 'user', 'content': 'Hello, how are you?'},
#   {'role': 'assistant',
#    'content': "Hello! I'm doing great, thank you for asking! 😊 I'm here and ready to help you with any math questions you might have. Whether it's algebra, geometry, fractions, or anything else that's puzzling you - just let me know what you'd like to work on today! \n\nHow are you doing? Ready to dive into some math learning together?"}],
#  'session_id': 'default_session'}

# %%
# 测试题目
test_problem = """25.(10分)如图,数轴上点A表示的数为a,点B表示的数为b.满足 |a+5|+(b-8)^2=0 ,机器人M从点A出发,以每秒4个单位长度的速度向右运动,1秒后,机器人N从点B出发,以每
秒2个单位长度的速度向左运动.根据机器人程序设定,机器人 M遇到机器人N后立即降速,以原速的一半返回,与此同时,机器人N以原速折返.设机器人 M运动时间为t秒.

(1)点A与点B之间的距离是_:
(2)求两个机器人 M、 N相遇的时间t及相遇点P所表示的数:
(3)两个机器人在相遇点P折返后,是否存在某一时刻,使得机器人M到点A的距离与机器人N到点B的距离之和为10?若存在,求出此时 t的值及机器人N所在位置表示的数:若不存在,请说明理由."""

agent.analyze_math_problem(test_problem)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 9
#       1 # 测试题目
#       2 test_problem = """25.(10分)如图,数轴上点A表示的数为a,点B表示的数为b.满足 |a+5|+(b-8)^2=0 ,机器人M从点A出发,以每秒4个单位长度的速度向右运动,1秒后,机器人N从点B出发,以每
#       3 秒2个单位长度的速度向左运动.根据机器人程序设定,机器人 M遇到机器人N后立即降速,以原速的一半返回,与此同时,机器人N以原速折返.设机器人 M运动时间为t秒.
#       4
#       5 (1)点A与点B之间的距离是_:
#       6 (2)求两个机器人 M、 N相遇的时间t及相遇点P所表示的数:
#       7 (3)两个机器人在相遇点P折返后,是否存在某一时刻,使得机器人M到点A的距离与机器人N到点B的距离之和为10?若存在,求出此时 t的值及机器人N所在位置表示的数:若不存在,请说明理由."""
# ----> 9 agent.analyze_math_problem(test_problem)
#
# AttributeError: 'SimpleChatService' object has no attribute 'analyze_math_problem'
